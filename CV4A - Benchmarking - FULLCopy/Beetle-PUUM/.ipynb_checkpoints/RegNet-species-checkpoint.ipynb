# %%
import torch
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from transformers import AutoProcessor, AutoModel
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, matthews_corrcoef

# %%
file_path = "/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/1. Completed_Data/CanonBeetles.csv"

canon_df = pd.read_csv(file_path)

canon_df["ImageFilePath"] = canon_df["cropped_image_path"].apply(lambda x: f"/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/CANON/{x}")

df = canon_df[['ImageFilePath', 'ScientificName']]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model_name = "facebook/regnet-y-040"

model = AutoModel.from_pretrained(model_name).eval().to(device)

processor = AutoProcessor.from_pretrained("facebook/regnet-y-040")

# %%
def extract_features(image_path) :
    
    image = Image.open(image_path).convert("RGB")
    
    inputs = processor(images=image, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    features = outputs.last_hidden_state.mean(dim=1)
    
    return features.cpu().numpy().flatten()

# %%
X = np.vstack([extract_features(img) for img in tqdm(df["ImageFilePath"])])

le = LabelEncoder()

y = le.fit_transform(df["ScientificName"])

df_indices = df.index 

X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(X, y, df_indices, test_size=0.2, random_state=42)

test_df = df.loc[test_idx].copy()

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)
# Out:
#  24%|██▍       | 395/1622 [00:34<01:42, 11.94it/s]

# %%
seed = 99

models = {
    "NaiveBayes": GaussianNB(),
    "LogisticRegression": LogisticRegression(max_iter=100),
    "SVMLinear": SVC(kernel="linear"),
    "SVMPolynomial": SVC(kernel="poly", degree=4),
    "SVMRadialBasis": SVC(kernel="rbf", degree=4),
    "NearestNeighbor": KNeighborsClassifier(n_neighbors=5),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=seed),    
    "MLP_Baseline": MLPClassifier(hidden_layer_sizes=(256, 128), activation='logistic', max_iter=200, random_state=seed),
    "MLP_BaselineX": MLPClassifier(hidden_layer_sizes=(100,), activation='logistic', max_iter=200, random_state=seed),
    "MLP_Deep": MLPClassifier(hidden_layer_sizes=(512, 256, 128), max_iter=300, random_state=seed),
    "MLP_Light": MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=150, random_state=seed),
    "MLP_Sigmoid": MLPClassifier(hidden_layer_sizes=(256, 128), activation='logistic', max_iter=200, random_state=seed),
    "MLP_Tanh": MLPClassifier(hidden_layer_sizes=(256, 128), activation='tanh', max_iter=200, random_state=seed),
    "MLP_Regularized": MLPClassifier(hidden_layer_sizes=(256, 128), alpha=0.001, max_iter=250, random_state=seed),
    "MLP_SGD": MLPClassifier(hidden_layer_sizes=(256, 128), solver='sgd', learning_rate='adaptive', max_iter=300, random_state=seed)
}

predictions = {}

metrics = {}

for name, model in models.items():
    
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
    predictions[name] = preds
    
    acc = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds, average="weighted")
    rec = recall_score(y_test, preds, average="weighted")
    f1 = f1_score(y_test, preds, average="weighted")
    bal_acc = balanced_accuracy_score(y_test, preds)
    mcc = matthews_corrcoef(y_test, preds)
    
    metrics[name] = {"Model": name, "Accuracy": acc, "Precision": prec, "Recall": rec, "F1-Score": f1, "Balanced Acc": bal_acc, "MCC": mcc}
    print(f"{name:<25} | Acc: {acc:.2%} | Prec: {prec:.2%} | Rec: {rec:.2%} | F1: {f1:.2%} | Bal Acc: {bal_acc:.2%} | MCC: {mcc:.4f}")


metrics_df = pd.DataFrame(metrics).T
# Out:
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# NaiveBayes                | Acc: 75.00% | Prec: 88.89% | Rec: 75.00% | F1: 77.49% | Bal Acc: 84.38% | MCC: 0.5528
# LogisticRegression        | Acc: 80.00% | Prec: 86.29% | Rec: 80.00% | F1: 82.67% | Bal Acc: 78.12% | MCC: 0.5035
# SVMLinear                 | Acc: 75.00% | Prec: 85.85% | Rec: 75.00% | F1: 79.54% | Bal Acc: 75.00% | MCC: 0.4478
# SVMPolynomial             | Acc: 80.00% | Prec: 64.00% | Rec: 80.00% | F1: 71.11% | Bal Acc: 50.00% | MCC: 0.0000
# SVMRadialBasis            | Acc: 80.00% | Prec: 84.29% | Rec: 80.00% | F1: 81.33% | Bal Acc: 78.12% | MCC: 0.4910
# NearestNeighbor           | Acc: 85.00% | Prec: 86.67% | Rec: 85.00% | F1: 85.59% | Bal Acc: 81.25% | MCC: 0.5774
# RandomForest              | Acc: 75.00% | Prec: 88.89% | Rec: 75.00% | F1: 77.49% | Bal Acc: 84.38% | MCC: 0.5528
# MLP_Baseline              | Acc: 75.00% | Prec: 82.42% | Rec: 75.00% | F1: 77.12% | Bal Acc: 75.00% | MCC: 0.4193
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# MLP_Deep                  | Acc: 65.00% | Prec: 81.30% | Rec: 65.00% | F1: 70.17% | Bal Acc: 68.75% | MCC: 0.3293
# MLP_Light                 | Acc: 75.00% | Prec: 82.42% | Rec: 75.00% | F1: 77.12% | Bal Acc: 75.00% | MCC: 0.4193
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (150) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# MLP_Sigmoid               | Acc: 80.00% | Prec: 93.33% | Rec: 80.00% | F1: 84.57% | Bal Acc: 87.50% | MCC: 0.6255
# MLP_Tanh                  | Acc: 80.00% | Prec: 91.43% | Rec: 80.00% | F1: 83.12% | Bal Acc: 87.50% | MCC: 0.6158
# MLP_Regularized           | Acc: 75.00% | Prec: 82.42% | Rec: 75.00% | F1: 77.12% | Bal Acc: 75.00% | MCC: 0.4193
# MLP_SGD                   | Acc: 70.00% | Prec: 80.83% | Rec: 70.00% | F1: 72.86% | Bal Acc: 71.88% | MCC: 0.3572
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
test_df = test_df.assign(**{f"Pred_{name}": le.inverse_transform(pred) for name, pred in predictions.items()})
test_df.head(2)
# Out:
#                                           ImageFilePath          Genus  \
# 491   /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...  Mecyclothorax
# 1539  /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...        Trechus
#
#      Pred_NaiveBayes Pred_LogisticRegression Pred_SVMLinear  \
# 491          Trechus           Mecyclothorax  Mecyclothorax
# 1539         Trechus                 Trechus        Trechus
#
#      Pred_SVMPolynomial Pred_SVMRadialBasis Pred_NearestNeighbor  \
# 491       Mecyclothorax             Trechus              Trechus
# 1539      Mecyclothorax             Trechus              Trechus
#
#      Pred_RandomForest Pred_MLP_Baseline Pred_MLP_Deep Pred_MLP_Light  \
# 491            Trechus           Trechus       Trechus        Trechus
# 1539           Trechus           Trechus       Trechus        Trechus
#
#      Pred_MLP_Sigmoid  Pred_MLP_Tanh Pred_MLP_Regularized Pred_MLP_SGD
# 491     Mecyclothorax  Mecyclothorax              Trechus      Trechus
# 1539          Trechus        Trechus              Trechus      Trechus

# %%
metrics_df
# Out:
#                                  Model Accuracy Precision Recall  F1-Score  \
# NaiveBayes                  NaiveBayes     0.75  0.888889   0.75  0.774929
# LogisticRegression  LogisticRegression      0.8  0.862857    0.8  0.826667
# SVMLinear                    SVMLinear     0.75  0.858462   0.75  0.795402
# SVMPolynomial            SVMPolynomial      0.8      0.64    0.8  0.711111
# SVMRadialBasis          SVMRadialBasis      0.8  0.842857    0.8  0.813333
# NearestNeighbor        NearestNeighbor     0.85  0.866667   0.85  0.855914
# RandomForest              RandomForest     0.75  0.888889   0.75  0.774929
# MLP_Baseline              MLP_Baseline     0.75  0.824176   0.75   0.77116
# MLP_Deep                      MLP_Deep     0.65  0.812987   0.65  0.701684
# MLP_Light                    MLP_Light     0.75  0.824176   0.75   0.77116
# MLP_Sigmoid                MLP_Sigmoid      0.8  0.933333    0.8  0.845714
# MLP_Tanh                      MLP_Tanh      0.8  0.914286    0.8  0.831169
# MLP_Regularized        MLP_Regularized     0.75  0.824176   0.75   0.77116
# MLP_SGD                        MLP_SGD      0.7  0.808333    0.7  0.728571
#
#                    Balanced Acc       MCC
# NaiveBayes              0.84375  0.552771
# LogisticRegression      0.78125  0.503499
# SVMLinear                  0.75  0.447767
# SVMPolynomial               0.5       0.0
# SVMRadialBasis          0.78125   0.49099
# NearestNeighbor          0.8125   0.57735
# RandomForest            0.84375  0.552771
# MLP_Baseline               0.75  0.419314
# MLP_Deep                 0.6875  0.329252
# MLP_Light                  0.75  0.419314
# MLP_Sigmoid               0.875  0.625463
# MLP_Tanh                  0.875  0.615831
# MLP_Regularized            0.75  0.419314
# MLP_SGD                 0.71875  0.357217

# %%
test_df.to_csv("/users/PAS2136/rayees/3. Benchmarking/Beetle-PUUM/35.RegNet-linear-probing-species.csv", index=False)
metrics_df.to_csv("/users/PAS2136/rayees/3. Benchmarking/Beetle-PUUM/35.RegNet-linear-probing-species-metrics.csv", index=False)
