# %%
import torch
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from transformers import ViltProcessor, ViltModel
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, matthews_corrcoef

# %%
file_path = "/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/1. Completed_Data/CanonBeetles.csv"

canon_df = pd.read_csv(file_path)

canon_df["ImageFilePath"] = canon_df["cropped_image_path"].apply(lambda x: f"/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/CANON/{x}")

df = canon_df[['ImageFilePath', 'Genus']]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model_name = "dandelin/vilt-b32-mlm"

model = ViltModel.from_pretrained(model_name).eval().to(device)

processor = ViltProcessor.from_pretrained(model_name)

# %%
def extract_features(image_path, taxa) :
    
    image = Image.open(image_path).convert("RGB")
    
    text = f"This is an image of a beetle, of genus : {taxa}"
    
    inputs = processor(images=image, text=text, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    features = outputs.last_hidden_state.mean(dim=1)
    
    return features.cpu().numpy().flatten()

# %%
X = np.vstack([extract_features(img, taxa) for img, taxa in zip(df["ImageFilePath"], df["Genus"])])

le = LabelEncoder()

y = le.fit_transform(df["Genus"])

df_indices = df.index 

X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(X, y, df_indices, test_size=0.2, random_state=42)

test_df = df.loc[test_idx].copy()

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
seed = 99

models = {
    "NaiveBayes": GaussianNB(),
    "LogisticRegression": LogisticRegression(max_iter=100),
    "SVMLinear": SVC(kernel="linear"),
    "SVMPolynomial": SVC(kernel="poly", degree=4),
    "SVMRadialBasis": SVC(kernel="rbf", degree=4),
    "NearestNeighbor": KNeighborsClassifier(n_neighbors=5),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=seed),    
    "MLP_Baseline": MLPClassifier(hidden_layer_sizes=(256, 128), alpha=0.001, max_iter=250, random_state=seed)
}

predictions = {}

metrics = {}

for name, model in models.items():
    
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
    predictions[name] = preds
    
    acc = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds, average="weighted")
    rec = recall_score(y_test, preds, average="weighted")
    f1 = f1_score(y_test, preds, average="weighted")
    bal_acc = balanced_accuracy_score(y_test, preds)
    mcc = matthews_corrcoef(y_test, preds)
    
    metrics[name] = {"Model": name, "Accuracy": acc, "Precision": prec, "Recall": rec, "F1-Score": f1, "Balanced Acc": bal_acc, "MCC": mcc}
    # print(f"{name:<25} | Acc: {acc:.2%} | Prec: {prec:.2%} | Rec: {rec:.2%} | F1: {f1:.2%} | Bal Acc: {bal_acc:.2%} | MCC: {mcc:.4f}")


metrics_df = pd.DataFrame(metrics).T
# Out:
# NaiveBayes                | Acc: 99.69% | Prec: 99.72% | Rec: 99.69% | F1: 99.70% | Bal Acc: 99.84% | MCC: 0.9936
# LogisticRegression        | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# SVMLinear                 | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# SVMPolynomial             | Acc: 90.46% | Prec: 91.50% | Rec: 90.46% | F1: 89.57% | Bal Acc: 67.98% | MCC: 0.7991
# SVMRadialBasis            | Acc: 99.08% | Prec: 99.10% | Rec: 99.08% | F1: 99.08% | Bal Acc: 96.91% | MCC: 0.9809
# NearestNeighbor           | Acc: 99.38% | Prec: 99.39% | Rec: 99.38% | F1: 99.36% | Bal Acc: 94.44% | MCC: 0.9871
# RandomForest              | Acc: 98.15% | Prec: 98.20% | Rec: 98.15% | F1: 97.96% | Bal Acc: 85.95% | MCC: 0.9615
# MLP_Baseline              | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# MLP_BaselineX             | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# MLP_Deep                  | Acc: 99.69% | Prec: 99.72% | Rec: 99.69% | F1: 99.70% | Bal Acc: 99.84% | MCC: 0.9936
# MLP_Light                 | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# MLP_Sigmoid               | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# MLP_Tanh                  | Acc: 99.69% | Prec: 99.70% | Rec: 99.69% | F1: 99.69% | Bal Acc: 99.84% | MCC: 0.9936
# MLP_Regularized           | Acc: 100.00% | Prec: 100.00% | Rec: 100.00% | F1: 100.00% | Bal Acc: 100.00% | MCC: 1.0000
# MLP_SGD                   | Acc: 100.00% | Prec: 100.00% | Rec: 100.00% | F1: 100.00% | Bal Acc: 100.00% | MCC: 1.0000

# %%
test_df = test_df.assign(**{f"Pred_{name}": le.inverse_transform(pred) for name, pred in predictions.items()})
test_df.head(2)
# Out:
#                                          ImageFilePath  \
# 135  /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...
# 844  /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...
#
#               ScientificName          Pred_NaiveBayes  \
# 135  Mecyclothorax discedens  Mecyclothorax discedens
# 844    Mecyclothorax konanus    Mecyclothorax konanus
#
#      Pred_LogisticRegression           Pred_SVMLinear  \
# 135  Mecyclothorax discedens  Mecyclothorax discedens
# 844    Mecyclothorax konanus    Mecyclothorax konanus
#
#           Pred_SVMPolynomial      Pred_SVMRadialBasis  \
# 135  Mecyclothorax discedens  Mecyclothorax discedens
# 844    Mecyclothorax konanus    Mecyclothorax konanus
#
#         Pred_NearestNeighbor        Pred_RandomForest        Pred_MLP_Baseline
# 135  Mecyclothorax discedens  Mecyclothorax discedens  Mecyclothorax discedens
# 844    Mecyclothorax konanus    Mecyclothorax konanus    Mecyclothorax konanus

# %%
metrics_df
# Out:
#                                  Model  Accuracy Precision    Recall  \
# NaiveBayes                  NaiveBayes  0.981538   0.97365  0.981538
# LogisticRegression  LogisticRegression  0.993846  0.991391  0.993846
# SVMLinear                    SVMLinear  0.990769  0.991184  0.990769
# SVMPolynomial            SVMPolynomial  0.738462  0.783507  0.738462
# SVMRadialBasis          SVMRadialBasis  0.972308  0.964043  0.972308
# NearestNeighbor        NearestNeighbor  0.966154  0.958377  0.966154
# RandomForest              RandomForest  0.953846   0.94704  0.953846
# MLP_Baseline              MLP_Baseline  0.996923  0.994231  0.996923
#
#                     F1-Score Balanced Acc       MCC
# NaiveBayes          0.977252     0.725524  0.972169
# LogisticRegression  0.992467     0.908508  0.990724
# SVMLinear           0.990807     0.900932  0.986067
# SVMPolynomial       0.710724     0.309581  0.606191
# SVMRadialBasis      0.965645     0.622145  0.957882
# NearestNeighbor     0.959156     0.593723  0.948406
# RandomForest        0.945101     0.544439  0.929597
# MLP_Baseline        0.995487     0.909091  0.995351

# %%
test_df.to_csv("/users/PAS2136/rayees/3. Benchmarking/Beetle-PUUM/28.ViLT-linear-probing-genus.csv", index=False)
metrics_df.to_csv("/users/PAS2136/rayees/3. Benchmarking/Beetle-PUUM/28.ViLT-linear-probing-genus-metrics.csv", index=False)
