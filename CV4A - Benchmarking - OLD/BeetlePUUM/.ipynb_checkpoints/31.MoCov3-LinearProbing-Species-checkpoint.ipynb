# %%
import torch
import numpy as np
import pandas as pd
from transformers import AutoImageProcessor, ViTMAEModel
from PIL import Image
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, matthews_corrcoef


file_path = "/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/1. Completed_Data/CanonBeetles.csv"
canon_df = pd.read_csv(file_path)
canon_df["ImageFilePath"] = canon_df["cropped_image_path"].apply(lambda x: f"/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/CANON/{x}")
cols = ['ImageFilePath', 'Genus']
df = canon_df[cols]


device = "cuda" if torch.cuda.is_available() else "cpu"

image_processor = AutoImageProcessor.from_pretrained("facebook/vit-mae-base", use_fast=True)
model = ViTMAEModel.from_pretrained("facebook/vit-mae-base").to(device)

def extract_features(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = image_processor(images=image, return_tensors="pt").to(device)
    with torch.no_grad():
        features = model(**inputs).last_hidden_state.mean(dim=1)
    return features.cpu().numpy()


X = np.vstack([extract_features(img) for img in df["ImageFilePath"]])

print(f"Extracted feature shape: {X.shape}")


le = LabelEncoder()

y = le.fit_transform(df["Genus"])

df_indices = df.index 

X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(X, y, df_indices, test_size=0.2, random_state=42)

test_df = df.loc[test_idx].copy()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
models = {
    "NaiveBayes": GaussianNB(),
    "LogisticRegression": LogisticRegression(max_iter=100),
    "SVMLinear": SVC(kernel="linear"),
    "SVMPolynomial": SVC(kernel="poly", degree=4),
    "SVMRadialBasis": SVC(kernel="rbf", degree=4),
    "NearestNeighbor": KNeighborsClassifier(n_neighbors=5),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42),    
    "MLP_Baseline": MLPClassifier(hidden_layer_sizes=(256, 64), activation='logistic', max_iter=200, random_state=42),
    "MLP_Baseline": MLPClassifier(hidden_layer_sizes=(100,), max_iter=200, random_state=42),
    "MLP_Deep": MLPClassifier(hidden_layer_sizes=(512, 256, 128), max_iter=300, random_state=42),
    "MLP_Light": MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=150, random_state=42),
    "MLP_Sigmoid": MLPClassifier(hidden_layer_sizes=(256, 128), activation='logistic', max_iter=200, random_state=42),
    "MLP_Tanh": MLPClassifier(hidden_layer_sizes=(256, 128), activation='tanh', max_iter=200, random_state=42),
    "MLP_Regularized": MLPClassifier(hidden_layer_sizes=(256, 128), alpha=0.001, max_iter=250, random_state=42),
    "MLP_SGD": MLPClassifier(hidden_layer_sizes=(256, 128), solver='sgd', learning_rate='adaptive', max_iter=300, random_state=42)

}

predictions = {}

metrics = {}

for name, model in models.items():
    
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
    predictions[name] = preds
    
    acc = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds, average="weighted")
    rec = recall_score(y_test, preds, average="weighted")
    f1 = f1_score(y_test, preds, average="weighted")
    bal_acc = balanced_accuracy_score(y_test, preds)
    mcc = matthews_corrcoef(y_test, preds)
    
    metrics[name] = {"Model": name, "Accuracy": acc, "Precision": prec, "Recall": rec, "F1-Score": f1, "Balanced Acc": bal_acc, "MCC": mcc}
    print(f"{name:<25} | Acc: {acc:.2%} | Prec: {prec:.2%} | Rec: {rec:.2%} | F1: {f1:.2%} | Bal Acc: {bal_acc:.2%} | MCC: {mcc:.4f}")


metrics_df = pd.DataFrame(metrics).T

test_df = test_df.assign(**{f"Pred_{name}": le.inverse_transform(pred) for name, pred in predictions.items()})
# Out:
# NaiveBayes                | Acc: 73.23% | Prec: 74.36% | Rec: 73.23% | F1: 73.59% | Bal Acc: 75.45% | MCC: 0.4649
# LogisticRegression        | Acc: 92.62% | Prec: 92.71% | Rec: 92.62% | F1: 92.44% | Bal Acc: 81.25% | MCC: 0.8429
# SVMLinear                 | Acc: 93.23% | Prec: 93.30% | Rec: 93.23% | F1: 93.13% | Bal Acc: 84.36% | MCC: 0.8564
# SVMPolynomial             | Acc: 68.00% | Prec: 72.50% | Rec: 68.00% | F1: 58.94% | Bal Acc: 39.56% | MCC: 0.2270
# SVMRadialBasis            | Acc: 90.15% | Prec: 90.49% | Rec: 90.15% | F1: 88.83% | Bal Acc: 64.10% | MCC: 0.7875
# NearestNeighbor           | Acc: 77.85% | Prec: 79.66% | Rec: 77.85% | F1: 78.28% | Bal Acc: 74.26% | MCC: 0.5573
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# RandomForest              | Acc: 81.23% | Prec: 79.04% | Rec: 81.23% | F1: 78.90% | Bal Acc: 52.17% | MCC: 0.5846
# MLP_Baseline              | Acc: 92.31% | Prec: 92.40% | Rec: 92.31% | F1: 92.14% | Bal Acc: 81.09% | MCC: 0.8364
# MLP_Deep                  | Acc: 92.62% | Prec: 92.68% | Rec: 92.62% | F1: 92.52% | Bal Acc: 83.87% | MCC: 0.8434
# MLP_Light                 | Acc: 92.92% | Prec: 93.00% | Rec: 92.92% | F1: 92.83% | Bal Acc: 84.20% | MCC: 0.8502
# MLP_Sigmoid               | Acc: 92.31% | Prec: 92.43% | Rec: 92.31% | F1: 92.04% | Bal Acc: 78.47% | MCC: 0.8359
# MLP_Tanh                  | Acc: 89.85% | Prec: 90.30% | Rec: 89.85% | F1: 89.82% | Bal Acc: 80.51% | MCC: 0.7933
# MLP_Regularized           | Acc: 93.23% | Prec: 93.31% | Rec: 93.23% | F1: 93.14% | Bal Acc: 84.53% | MCC: 0.8567
# MLP_SGD                   | Acc: 91.08% | Prec: 91.30% | Rec: 91.08% | F1: 90.66% | Bal Acc: 74.72% | MCC: 0.8086

# %%
test_df.head(2)
# Out:
#                                          ImageFilePath          Genus  \
# 135  /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...  Mecyclothorax
# 844  /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...  Mecyclothorax
#
#     Pred_NaiveBayes Pred_LogisticRegression Pred_SVMLinear Pred_SVMPolynomial  \
# 135   Mecyclothorax           Mecyclothorax  Mecyclothorax      Mecyclothorax
# 844   Mecyclothorax           Mecyclothorax  Mecyclothorax      Mecyclothorax
#
#     Pred_SVMRadialBasis Pred_NearestNeighbor Pred_RandomForest  \
# 135       Mecyclothorax        Mecyclothorax     Mecyclothorax
# 844       Mecyclothorax        Mecyclothorax     Mecyclothorax
#
#     Pred_MLP_Baseline  Pred_MLP_Deep Pred_MLP_Light Pred_MLP_Sigmoid  \
# 135     Mecyclothorax  Mecyclothorax  Mecyclothorax    Mecyclothorax
# 844     Mecyclothorax  Mecyclothorax  Mecyclothorax    Mecyclothorax
#
#      Pred_MLP_Tanh Pred_MLP_Regularized   Pred_MLP_SGD
# 135  Mecyclothorax        Mecyclothorax  Mecyclothorax
# 844  Mecyclothorax        Mecyclothorax  Mecyclothorax

# %%
metrics_df.head(2)
# Out:
#                                  Model  Accuracy Precision    Recall  \
# NaiveBayes                  NaiveBayes  0.732308  0.743564  0.732308
# LogisticRegression  LogisticRegression  0.926154  0.927082  0.926154
#
#                     F1-Score Balanced Acc       MCC
# NaiveBayes          0.735935     0.754453  0.464896
# LogisticRegression  0.924402     0.812525  0.842861
