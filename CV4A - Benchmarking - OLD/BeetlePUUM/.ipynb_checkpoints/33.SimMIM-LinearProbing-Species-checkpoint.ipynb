# %%
import torch
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from transformers import AutoModel, AutoProcessor
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, matthews_corrcoef


model = AutoModel.from_pretrained("facebook/levit-128S").eval().to("cuda" if torch.cuda.is_available() else "cpu")
processor = AutoProcessor.from_pretrained("facebook/levit-128S")

# Load dataset
file_path = "/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/1. Completed_Data/CanonBeetles.csv"
canon_df = pd.read_csv(file_path)
canon_df["ImageFilePath"] = canon_df["cropped_image_path"].apply(lambda x: f"/fs/ess/PAS2136/Hawaii-2025/beetles_intake/BeetlePUUM/CANON/{x}")
df = canon_df[['ImageFilePath', 'Genus']].sample(n=100, random_state=99)  # Subsample for faster testing

device = "cuda" if torch.cuda.is_available() else "cpu"

def extract_features(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(images=image, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    features = outputs.last_hidden_state.mean(dim=1)
    return features.cpu().numpy().flatten()


X = np.vstack([extract_features(img) for img in tqdm(df["ImageFilePath"])])

print(f"Extracted feature shape: {X.shape}")


le = LabelEncoder()

y = le.fit_transform(df["Genus"])

df_indices = df.index 

X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(X, y, df_indices, test_size=0.2, random_state=42)

test_df = df.loc[test_idx].copy()

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)
# Out:
# config.json:   0%|          | 0.00/70.0k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/32.1M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/268 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 100%|██████████| 100/100 [00:02<00:00, 37.10it/s]
# Extracted feature shape: (100, 384)

# %%
models = {
    "NaiveBayes": GaussianNB(),
    "LogisticRegression": LogisticRegression(max_iter=100),
    "SVMLinear": SVC(kernel="linear"),
    "SVMPolynomial": SVC(kernel="poly", degree=4),
    "SVMRadialBasis": SVC(kernel="rbf", degree=4),
    "NearestNeighbor": KNeighborsClassifier(n_neighbors=5),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42),    
    "MLP_Baseline": MLPClassifier(hidden_layer_sizes=(256, 64), activation='logistic', max_iter=200, random_state=42),
    "MLP_Baseline": MLPClassifier(hidden_layer_sizes=(100,), max_iter=200, random_state=42),
    "MLP_Deep": MLPClassifier(hidden_layer_sizes=(512, 256, 128), max_iter=300, random_state=42),
    "MLP_Light": MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=150, random_state=42),
    "MLP_Sigmoid": MLPClassifier(hidden_layer_sizes=(256, 128), activation='logistic', max_iter=200, random_state=42),
    "MLP_Tanh": MLPClassifier(hidden_layer_sizes=(256, 128), activation='tanh', max_iter=200, random_state=42),
    "MLP_Regularized": MLPClassifier(hidden_layer_sizes=(256, 128), alpha=0.001, max_iter=250, random_state=42),
    "MLP_SGD": MLPClassifier(hidden_layer_sizes=(256, 128), solver='sgd', learning_rate='adaptive', max_iter=300, random_state=42)

}

predictions = {}

metrics = {}

for name, model in models.items():
    
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
    predictions[name] = preds
    
    acc = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds, average="weighted")
    rec = recall_score(y_test, preds, average="weighted")
    f1 = f1_score(y_test, preds, average="weighted")
    bal_acc = balanced_accuracy_score(y_test, preds)
    mcc = matthews_corrcoef(y_test, preds)
    
    metrics[name] = {"Model": name, "Accuracy": acc, "Precision": prec, "Recall": rec, "F1-Score": f1, "Balanced Acc": bal_acc, "MCC": mcc}
    print(f"{name:<25} | Acc: {acc:.2%} | Prec: {prec:.2%} | Rec: {rec:.2%} | F1: {f1:.2%} | Bal Acc: {bal_acc:.2%} | MCC: {mcc:.4f}")


metrics_df = pd.DataFrame(metrics).T

test_df = test_df.assign(**{f"Pred_{name}": le.inverse_transform(pred) for name, pred in predictions.items()})
# Out:
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# NaiveBayes                | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# LogisticRegression        | Acc: 100.00% | Prec: 100.00% | Rec: 100.00% | F1: 100.00% | Bal Acc: 100.00% | MCC: 1.0000
# SVMLinear                 | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# SVMPolynomial             | Acc: 80.00% | Prec: 64.00% | Rec: 80.00% | F1: 71.11% | Bal Acc: 50.00% | MCC: 0.0000
# SVMRadialBasis            | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# NearestNeighbor           | Acc: 100.00% | Prec: 100.00% | Rec: 100.00% | F1: 100.00% | Bal Acc: 100.00% | MCC: 1.0000
# RandomForest              | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# MLP_Baseline              | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# MLP_Deep                  | Acc: 100.00% | Prec: 100.00% | Rec: 100.00% | F1: 100.00% | Bal Acc: 100.00% | MCC: 1.0000
# MLP_Light                 | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# MLP_Sigmoid               | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# MLP_Tanh                  | Acc: 90.00% | Prec: 96.00% | Rec: 90.00% | F1: 92.44% | Bal Acc: 93.75% | MCC: 0.7685
# MLP_Regularized           | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# MLP_SGD                   | Acc: 95.00% | Prec: 96.00% | Rec: 95.00% | F1: 95.20% | Bal Acc: 96.88% | MCC: 0.8660
# /users/PAS2136/rayees/myenv/lib64/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
test_df.head(2)
# Out:
#                                           ImageFilePath          Genus  \
# 491   /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...  Mecyclothorax
# 1539  /fs/ess/PAS2136/Hawaii-2025/beetles_intake/Bee...        Trechus
#
#      Pred_NaiveBayes Pred_LogisticRegression Pred_SVMLinear  \
# 491    Mecyclothorax           Mecyclothorax  Mecyclothorax
# 1539         Trechus                 Trechus        Trechus
#
#      Pred_SVMPolynomial Pred_SVMRadialBasis Pred_NearestNeighbor  \
# 491       Mecyclothorax       Mecyclothorax        Mecyclothorax
# 1539      Mecyclothorax             Trechus              Trechus
#
#      Pred_RandomForest Pred_MLP_Baseline  Pred_MLP_Deep Pred_MLP_Light  \
# 491      Mecyclothorax     Mecyclothorax  Mecyclothorax  Mecyclothorax
# 1539           Trechus           Trechus        Trechus        Trechus
#
#      Pred_MLP_Sigmoid  Pred_MLP_Tanh Pred_MLP_Regularized   Pred_MLP_SGD
# 491     Mecyclothorax  Mecyclothorax        Mecyclothorax  Mecyclothorax
# 1539          Trechus        Trechus              Trechus        Trechus

# %%
metrics_df
# Out:
#                                  Model Accuracy Precision Recall  F1-Score  \
# NaiveBayes                  NaiveBayes     0.95      0.96   0.95  0.951971
# LogisticRegression  LogisticRegression      1.0       1.0    1.0       1.0
# SVMLinear                    SVMLinear     0.95      0.96   0.95  0.951971
# SVMPolynomial            SVMPolynomial      0.8      0.64    0.8  0.711111
# SVMRadialBasis          SVMRadialBasis     0.95      0.96   0.95  0.951971
# NearestNeighbor        NearestNeighbor      1.0       1.0    1.0       1.0
# RandomForest              RandomForest     0.95      0.96   0.95  0.951971
# MLP_Baseline              MLP_Baseline     0.95      0.96   0.95  0.951971
# MLP_Deep                      MLP_Deep      1.0       1.0    1.0       1.0
# MLP_Light                    MLP_Light     0.95      0.96   0.95  0.951971
# MLP_Sigmoid                MLP_Sigmoid     0.95      0.96   0.95  0.951971
# MLP_Tanh                      MLP_Tanh      0.9      0.96    0.9  0.924444
# MLP_Regularized        MLP_Regularized     0.95      0.96   0.95  0.951971
# MLP_SGD                        MLP_SGD     0.95      0.96   0.95  0.951971
#
#                    Balanced Acc       MCC
# NaiveBayes              0.96875  0.866025
# LogisticRegression          1.0       1.0
# SVMLinear               0.96875  0.866025
# SVMPolynomial               0.5       0.0
# SVMRadialBasis          0.96875  0.866025
# NearestNeighbor             1.0       1.0
# RandomForest            0.96875  0.866025
# MLP_Baseline            0.96875  0.866025
# MLP_Deep                    1.0       1.0
# MLP_Light               0.96875  0.866025
# MLP_Sigmoid             0.96875  0.866025
# MLP_Tanh                 0.9375  0.768498
# MLP_Regularized         0.96875  0.866025
# MLP_SGD                 0.96875  0.866025
